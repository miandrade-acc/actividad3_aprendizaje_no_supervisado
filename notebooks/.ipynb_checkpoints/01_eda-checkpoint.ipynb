# %%
# ========================================================
# NOTEBOOK 01 - ANÁLISIS EXPLORATORIO DE DATOS (EDA)
# ========================================================
# Este cuaderno realiza una exploración general del dataset
# "Online Retail", detecta valores nulos y duplicados,
# visualiza distribuciones y deja una versión limpia del dataset
# para los modelos de clustering.

# %%
# ===============================================
# BLOQUE 1 - Importación de librerías necesarias
# ===============================================

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Configuración visual de gráficos
sns.set(style="whitegrid")

# %%
# ===============================================
# BLOQUE 2 - Carga del dataset original
# ===============================================

# Cargamos el archivo previamente convertido a CSV
df = pd.read_csv('../data/online_retail.csv')

# Confirmamos forma del dataset
print(f"✅ Dataset cargado correctamente. Dimensiones: {df.shape}")
# Out:
# ✅ Dataset cargado correctamente. Dimensiones: (541909, 8)

# %%
# ===============================================
# BLOQUE 3 - Estructura general del dataset
# ===============================================

print("📌 Columnas disponibles:")
print(df.columns.tolist())

print("\n🔍 Tipos de datos:")
print(df.dtypes)
# Out:
# 📌 Columnas disponibles:
# ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']
#
# 🔍 Tipos de datos:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
# ===============================================
# BLOQUE 4 - Revisión de valores nulos y duplicados
# ===============================================

print("🚫 Valores nulos por columna:")
print(df.isnull().sum())

print(f"\n📛 Registros duplicados: {df.duplicated().sum()}")
# Out:
# 🚫 Valores nulos por columna:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64
#
# 📛 Registros duplicados: 5268

# %%
# ===============================================
# BLOQUE 5 - Visualización de valores faltantes
# ===============================================

plt.figure(figsize=(10, 4))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title("Mapa de calor de valores nulos")
plt.tight_layout()
plt.show()

# %%
# ===============================================
# BLOQUE 6 - Limpieza de datos
# ===============================================

# Eliminamos registros sin CustomerID y hacemos copia segura
df_clean = df.dropna(subset=['CustomerID']).copy()

# Convertimos el ID de cliente a entero
df_clean['CustomerID'] = df_clean['CustomerID'].astype(int)

# Eliminamos columnas no útiles para clustering
df_clean.drop(columns=['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate'], inplace=True)

# Confirmamos estructura limpia
print(f"✅ Dataset limpio. Filas: {df_clean.shape[0]} | Columnas: {df_clean.columns.tolist()}")
# Out:
# ✅ Dataset limpio. Filas: 406829 | Columnas: ['Quantity', 'UnitPrice', 'CustomerID', 'Country']

# %%
# ===============================================
# BLOQUE 7 - Distribución de cantidad de productos
# ===============================================

plt.figure(figsize=(8, 4))
sns.histplot(df_clean['Quantity'], bins=50, kde=True)
plt.title("Distribución de Cantidad de Productos Comprados")
plt.tight_layout()
plt.show()

# %%
# ===============================================
# BLOQUE 8 - Distribución del precio unitario
# ===============================================

plt.figure(figsize=(8, 4))
sns.histplot(df_clean['UnitPrice'], bins=50, kde=True)
plt.title("Distribución del Precio Unitario")
plt.tight_layout()
plt.show()

# %%
# ===============================================
# BLOQUE 9 - Países con más transacciones
# ===============================================

top_paises = df_clean['Country'].value_counts().head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=top_paises.values, y=top_paises.index)
plt.title("Top 10 países con más transacciones")
plt.xlabel("Número de transacciones")
plt.ylabel("País")
plt.tight_layout()
plt.show()

# %%
# ===============================================
# BLOQUE 10 - Guardar el dataset limpio
# ===============================================

# Guardamos una copia del dataset limpio para los modelos
df_clean.to_csv('../data/online_retail_clean.csv', index=False)
print("📁 Dataset limpio guardado como: online_retail_clean.csv")
# Out:
# 📁 Dataset limpio guardado como: online_retail_clean.csv
